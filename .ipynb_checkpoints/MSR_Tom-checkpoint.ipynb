# %%
import pandas as pd
import numpy as np
from collections import Counter
import spacy
import datetime
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = pd.read_csv('./data/PoPCites2.csv')
#data = pd.read_csv('data/PoPCites2.csv',usecols = '')

# RQ1: Which technologies have been investigated in the last decade?

# RQ2: In which phase of the technology life cycle path are the technologies?
# - Interest in topic: #Papers on a topic over time
# - Parallel dazu: Interest in topic: Number of citations to papers on a topic over time
#- Publikationstyp: Workshop -> Conference -> Journal 

# RQ3: How stable is the community working on the topics (new authors emerging, authors staying on for the whole time,
# or authors “leaving” the area)?

#data.info()
data.head(20)
# Out:
#     Cites                                       Authors  \
# 0     435                                        R Mall
# 1    1226                M Brambilla, J Cabot, M Wimmer
# 2     118                                C Page, HW Six
# 3      22                                       G Booch
# 4     142  B Kitchenham, L Madeyski, D Budgen, J Keung…
# 5     179         S Amershi, A Begel, C Bird, R DeLine…
# 6      59                                      RJ Leach
# 7      48                         KJ Stol, B Fitzgerald
# 8      59         A Arpteg, B Brinne, L Crnkovic-Friis…
# 9     254               K Mao, L Capra, M Harman, Y Jia
# 10    458                         B Fitzgerald, KJ Stol
# 11    233                 S Porru, A Pinna, M Marchesi…
# 12     50     E Klotins, M Unterkalmsteiner, T Gorschek
# 13     18                                         T Xie
# 14     54   X Larrucea, A Combelles, J Favaro, K Taneja
# 15    123                                   NM Devadiga
# 16     27                 R Feldt, FG de Oliveira Neto…
# 17    155                                       D Weyns
# 18     25                        Z Kurtanović, W Maalej
# 19     45           M Marques, SF Ochoa, MC Bastarrica…
#
#                                                 Title  Year  \
# 0                Fundamentals of software engineering  2018
# 1       Model-driven software engineering in practice  2017
# 2                                Software Engineering  2017
# 3                 The history of software engineering  2018
# 4   Robust statistical methods for empirical softw...  2017
# 5   Software engineering for machine learning: A c...  2019
# 6                Introduction to software engineering  2018
# 7            The ABC of software engineering research  2018
# 8    Software engineering challenges of deep learning  2018
# 9   A survey of the use of crowdsourcing in softwa...  2017
# 10  Continuous software engineering: A roadmap and...  2017
# 11  Blockchain-oriented software engineering: chal...  2017
# 12  Software engineering in start-up companies: An...  2019
# 13  Intelligent software engineering: Synergy betw...  2018
# 14    Software engineering for the internet of things  2017
# 15  Software engineering education: Converging wit...  2017
# 16  Ways of applying artificial intelligence in so...  2018
# 17      Software engineering of self-adaptive systems  2019
# 18          On user rationale in software engineering  2018
# 19  Enhancing the student learning experience in s...  2017
#
#                                               Source                Publisher  \
# 0                                                NaN         books.google.com
# 1                          … on software engineering       morganclaypool.com
# 2                        Larsen and Keller Education  repo.mimitlibrary.ac.in
# 3                                      IEEE Software      ieeexplore.ieee.org
# 4                             … Software Engineering                 Springer
# 5                                    … Engineering …      ieeexplore.ieee.org
# 6                                                NaN         books.google.com
# 7     ACM Transactions on Software Engineering and …               dl.acm.org
# 8                           … Software Engineering …      ieeexplore.ieee.org
# 9                    Journal of Systems and Software                 Elsevier
021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN   142
# 5   2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN   179
# 6   2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    59
# 7   2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    48
# 8   2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    59
# 9   2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN   254
# 10  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN   458
# 11  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN   233
# 12  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    50
# 13  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    18
# 14  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    54
# 15  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN   123
# 16  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    27
# 17  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN   155
# 18  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    25
# 19  2021-04-19 20:05:26  ...    NaN    NaN        NaN      NaN    45
#
#     CitesPerYear  CitesPerAuthor  AuthorCount  Age  \
# 0         145.00             435            1    3
# 1         306.50             409            3    4
# 2          29.50              59            2    4
# 3           7.33              22            1    3
# 4          35.50              28            5    4
# 5          89.50              36            5    2
# 6          19.67              59            1    3
# 7          16.00              24            2    3
# 8          19.67              15            4    3
# 9          63.50              64            4    4
# 10        114.50             229            2    4
# 11         58.25              58            4    4
# 12         25.00              17            3    2
# 13          6.00              18            1    3
# 14         13.50              14            4    4
# 15         30.75             123            1    4
# 16          9.00               9            3    3
# 17         77.50             155            1    2
# 18          8.33              13            2    3
# 19         11.25              11            4    4
#
#                                              Abstract
# 0   This new edition of the book, is restructured ...
# 1   This book discusses how model-based approaches...
# 2   1. a) What are drawbacks of Spiral Model? b) W...
# 3   Grady Booch, one of UML's original authors, of...
# 4   There have been many changes in statistical th...
# 5   Recent advances in machine learning have stimu...
# 6   Practical Guidance on the Efficient Developmen...
# 7   A variety of research methods and techniques a...
# 8   Surprisingly promising results have been achie...
# 9   The term 'crowdsourcing'was initially introduc...
# 10  Throughout its short history, software develop...
# 11  In this work, we acknowledge the need for soft...
# 12  Context Start-up companies have become an impo...
# 13  As an example of exploiting the synergy betwee...
# 14  No consolidated set of software engineering be...
# 15  Startups are agents of change that bring in in...
# 16  As Artificial Intelligence (AI) techniques bec...
# 17  Modern software systems are expected to operat...
# 18  Rationale refers to the reasoning and justific...
# 19  Carrying out real-world software projects in t...
#
# [20 rows x 24 columns]

# %%
#Funktionen
def Count(data,count):
    cnt = Counter()
    for item in data: 
        cnt[item] += 1
    return cnt.most_common(count)

def CountCites(data,count):
    
    i = 0
    cnt = Counter()
    for cites,title in data['Cites','Title']: 
        cnt[title] += cites
    return cnt.most_common(count)

def CountWords(data,count):
    cnt = Counter()
    #Pandas.Series durchlaufen um die Title zu bekommen
    for index, value in data.items():
        words = value.lower().split(' ')
        #Title in Wörter teilen
        for word in words:
            #Aussortieren der Stopwords
            if not word in stopwords:
                #Für bestimmte Begriffe
                #for word in wordlist:
                cnt[word] += 1
    return cnt.most_common(count)

def CountToTfidf(counts):
    transformer = TfidfTransformer(smooth_idf=False)
    
    #Gewichtet die CountMatrix
    tfidf = transformer.fit_transform(counts)

    #Gibt Array zurück
    return tfidf.toarray()

def ListToDataFrame(l):
    ld = pd.DataFrame.from_dict(l)
    ld = ld.rename(columns={ 0:'word',1:'data'})
    ld = ld.set_index('word')
    return ld


def ListToDataArray(l,year):
    ld = pd.DataFrame.from_dict(l)
    ld = ld.rename(columns={ 0:'word',1:year})
    ld = ld.set_index('word')
    #Gibt Pandas.DataFrame zurück
    return ld


def TfidfVector(data):
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(data)
    print(vectorizer.get_feature_names())
    print(X.toarray())
    
def CountVector(data):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(data)
    print(vectorizer.get_feature_names())
    return X.toarray()

#FilteredByPublication

def FilteredByYear(data,year):
    databyyear = data.loc[data['Year'] == year]
    return databyyear
    
def TitleFilteredByYear(data,year):
    databyyear = data['Title'].loc[data['Year'] == year]
    return databyyear

def CountWordsByYear(data,year):
    #d = Pandas.Series
    d = FilteredByYear(data,year)
    l = CountWords(d['Title'],30)
    #Gibt List zurück
    return l

def CountWordsInAbstractByYear(data,year):
    d = FilteredByYear(data,year)
    l = CountWords(d['Abstract'],30)
    return l
    
def MergeDataFrames(data,anzahlJahre):
    year = datetime.datetime.now()
    year = year.year
    da = pd.DataFrame()
    for y in range(year - anzahlJahre, year):
        l = CountWordsByYear(data,y)
        p = ListToDataArray(l,y)
        if(da.empty):
            da = p
        else:
            da = da.merge(p, on= 'word' ,how='inner')
    return da       
    
def CosineSimilarity(data):
    return cosine_similarity(data,data)

def CreateDocTermMatrix(data):
    documents = []

    for text in data:
        documents.append(text)


    count_vectorizer = CountVectorizer(stop_words='english')
    #count_vectorizer = CountVectorizer()
    sparse_matrix = count_vectorizer.fit_transform(documents)
    print(sparse_matrix)

    doc_term_matrix = sparse_matrix.todense()
    return pd.DataFrame(doc_term_matrix, columns=count_vectorizer.get_feature_names())

# %%
#Variablen erstellen
title = data['Title']
publisher = data['Publisher']
year = data['Year']

wordlist = [
    'DevOps',
    'engineering',
    'Software',
    'Engineering',
    'software'
    
]
stopwords =[
    'this',
    'is',
    'none',
    'in',
    'of',
    'A',
    'a',
    'and',
    'for',
    'with',
    'on',
    'the',
    'to',
    'an',
    'be',
    'as',
    'has',
    'are',
    'we',
    'been',
    'by',
    'many',
    'that',
    'at',
    '...',
    'more',
    'them',
    'have',
    'such'
]

# %%
import en_core_web_md
nlp = en_core_web_md.load()
data["count"] = 2
cnt = Counter()

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS  

print('Anzahl an Stoppwörtern: %d' % len(spacy_stopwords))
print('Ersten 20 Stoppwörter: %s' % list(spacy_stopwords)[:10])
for word in list(spacy_stopwords):
    nlp.vocab[word].is_stop = True
   

#nlp.add_pipe(texts)
# Out:
# Anzahl an Stoppwörtern: 326
# Ersten 20 Stoppwörter: ['from', 'been', 'done', 'though', 'under', 'latter', 'hers', 'everything', 'name', 'me']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-92c25b53201b> in <module>
#       7
#       8
# ----> 9 nlp.add_pipe(texts)
#      10
#      11
#
# NameError: name 'texts' is not defined

# %%
def ErstelleDoc(data):  
    for text in data:
        doc = nlp(text)
        
        
        

        #cnt[Token] += 1
        Token = [token.text for token in doc if not token.is_stop]
        for word in /
        print(Token)


ErstelleDoc(data['Abstract'])
#c.most_common(50)
